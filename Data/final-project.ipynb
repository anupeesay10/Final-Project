# %% [markdown]
# # Pittburgh neighborhood crash data

# %% [markdown]
# ### I analysis the crash data for whole county and the Neighborhood county of our county at first, and it tell me that the percentage of each crash type of accident is almost same for all area, therefor I only need to consider about the number of collision

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

allegheny_crash_data = pd.read_csv("2015allegheny.csv", sep=",", low_memory=False)
beaver_crash_data = pd.read_csv("2015beaver.csv", sep=",", low_memory=False)
butler_crash_data = pd.read_csv("2015butler.csv", sep=",", low_memory=False)
washington_crash_data = pd.read_csv("2015washington.csv", sep=",", low_memory=False)
westmoreland_crash_data = pd.read_csv("2015westmoreland.csv", sep=",", low_memory=False)

# %% [markdown]
# ## Total crash count
# ### Our Allegheny has much more accident than Neighborhood county, which is more than the sum of all accident happen in our Neighborhood country

# %%
pd.Series([allegheny_crash_data['DISTRICT'].count(),beaver_crash_data['DISTRICT'].count(),butler_crash_data['DISTRICT'].count(),washington_crash_data['DISTRICT'].count(),westmoreland_crash_data['DISTRICT'].count()],
          index=["allegheny", "beaver", "butler", "washington", "westmoreland"]).plot.bar()

# %% [markdown]
# ## Pie chart for each county

# %% [markdown]
# ### Allegheny

# %%
dataframe = pd.DataFrame({'Name': ['Non collision', ' Rear-end', 'Head-on',  'Rear-to-rear', 'Angle', 'Sideswipe Same Direction', "Sideswipe Opposide", "Hit fixed object", "Hit pedestrian", "unknown"],
                          'votes_of_each_class': allegheny_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT']}) 
dataframe.groupby(['Name']).sum().plot( kind='pie', y='votes_of_each_class', autopct='%1.0f%%', figsize=(10,10))

# %% [markdown]
# ### Beaver

# %%
dataframe = pd.DataFrame({'Name': ['Non collision', ' Rear-end', 'Head-on',  'Rear-to-rear', 'Angle', 'Sideswipe Same Direction', "Sideswipe Opposide", "Hit fixed object", "Hit pedestrian", "unknown"],
                          'votes_of_each_class': beaver_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT']}) 
dataframe.groupby(['Name']).sum().plot( kind='pie', y='votes_of_each_class', autopct='%1.0f%%', figsize=(10,10))

# %% [markdown]
# ### Butler

# %%
dataframe = pd.DataFrame({'Name': ['Non collision', ' Rear-end', 'Head-on',  'Rear-to-rear', 'Angle', 'Sideswipe Same Direction', "Sideswipe Opposide", "Hit fixed object", "Hit pedestrian", "unknown"],
                          'votes_of_each_class': butler_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT']}) 
dataframe.groupby(['Name']).sum().plot( kind='pie', y='votes_of_each_class', autopct='%1.0f%%', figsize=(10,10))

# %% [markdown]
# ## Washington

# %%
dataframe = pd.DataFrame({'Name': ['Non collision', ' Rear-end', 'Head-on',  'Rear-to-rear', 'Angle', 'Sideswipe Same Direction', "Sideswipe Opposide", "Hit fixed object", "Hit pedestrian", "unknown"],
                          'votes_of_each_class': washington_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT']}) 
dataframe.groupby(['Name']).sum().plot( kind='pie', y='votes_of_each_class', autopct='%1.0f%%', figsize=(10,10))

# %% [markdown]
# ## Westmoreland

# %%
dataframe = pd.DataFrame({'Name': ['Non collision', ' Rear-end', 'Head-on',  'Rear-to-rear', 'Angle', 'Sideswipe Same Direction', "Sideswipe Opposide", "Hit fixed object", "Hit pedestrian", "unknown"],
                          'votes_of_each_class': westmoreland_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT']}) 
dataframe.groupby(['Name']).sum().plot( kind='pie', y='votes_of_each_class', autopct='%1.0f%%', figsize=(10,10))

# %% [markdown]
# ### Some of accident is much dangerous than other, but we can see that the percentage for each accident if almost same for every country. Therefor, accident type is not the thing we really need to consider about

# %% [markdown]
# ## Put all crash accident together to compare

# %%
df2 = pd.DataFrame([
                    [beaver_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][0], butler_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][0],
                    washington_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][0], westmoreland_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][0]],
                    [beaver_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][1], butler_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][1],
                    washington_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][1], westmoreland_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][1]],
                    [beaver_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][2], butler_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][2],
                    washington_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][2], westmoreland_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][2]],
                    [beaver_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][3], butler_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][3],
                    washington_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][3], westmoreland_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][3]],
                    [beaver_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][4], butler_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][4],
                    washington_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][4], westmoreland_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][4]],
                    [beaver_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][5], butler_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][5],
                    washington_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][5], westmoreland_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][5]],
                    [beaver_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][6], butler_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][6],
                    washington_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][6], westmoreland_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][6]],
                    [beaver_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][7], butler_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][7],
                    washington_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][7], westmoreland_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][7]],
                    [beaver_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][8], butler_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][8],
                    washington_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][8], westmoreland_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][8]],
                    [beaver_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][9], butler_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][9],
                    washington_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][9], westmoreland_crash_data.groupby("COLLISION_TYPE").count()['DISTRICT'][9]]
                   ], 
                   columns=["beaver", "butler", "washington", "westmoreland"], 
                   index=['Non collision', ' Rear-end', 'Head-on',  'Rear-to-rear', 'Angle', 'Sideswipe Same Direction', "Sideswipe Opposide", "Hit fixed object", "Hit pedestrian", "unknown"])

df2.plot(kind="bar", figsize=(10,10))

# %% [markdown]
# ### this is the bar chat that compare the count of each type of accident in those county, our county still has much more accident than others in everytype of county

# %%
import fpsnippets
neighborhood = []
for each in range(0, allegheny_crash_data['DISTRICT'].count()):
    n = fpsnippets.geo_to_neighborhood(allegheny_crash_data["DEC_LAT"][each], allegheny_crash_data["DEC_LONG"][each])
    if n is not None:
        neighborhood.append(n)
crash_data = pd.DataFrame({"neigborhood":neighborhood})
crash_data.to_csv("crash_data.csv", index=False)

# %%
data = pd.read_csv('crash_data.csv')
data["neigborhood"].value_counts()
# Out:
# Central Business District    236
# Squirrel Hill South          211
# Brookline                    151
# South Side Flats             130
# Strip District               128
#                             ...
# Bedford Dwellings              4
# Esplen                         3
# New Homestead                  3
# Arlington Heights              2
# Mt. Oliver                     2
# Name: neigborhood, Length: 90, dtype: int64

# %% [markdown]
# ### This is the data about total crash number that I get for all neighborhood in pittburgh

# %%
data["neigborhood"].value_counts().sort_index().plot(kind='bar', width=.8, figsize=(20, 6), rot=90)

plt.title('Number of crash per Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Number of crash')
plt.show()

# %% [markdown]
# # Fire Incidents in Pittsburgh
# ## By Anirudh Peesay

# %% [markdown]
# ![image](https://media.giphy.com/media/v1.Y2lkPTc5MGI3NjExOHFwcjZxMWowbmJ3ZTJkNW5zZWR5MndzZGRrMmQ4NzV4Mm50YWsweiZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/nrXif9YExO9EI/giphy.gif)

# %% [markdown]
# We start by importing the fires data using pandas.

# %%
import pandas as pd

fire = pd.read_csv("fires_list.tsv",sep="\t")

# %% [markdown]
# We want to analyze the fire incidents in each neighborhood. For example, we can look at Fineview:

# %%
query_mask = fire['neighborhood']== "Fineview"
Fineview_fires = fire[query_mask]
Fineview_fires.head(10)
# Out:
#        _id     call_no  incident_type                     type_description  \
# 3        4  F170043431          131.0               Passenger vehicle fire
# 206    207  F140015339          131.0               Passenger vehicle fire
# 219    220  F140004033          111.0                        Building fire
# 258    259  F140008680          131.0               Passenger vehicle fire
# 833    834  F150056424          131.0               Passenger vehicle fire
# 845    846  F160022797          150.0          Outside rubbish fire, Other
# 1212  1213  F160039740          113.0  Cooking fire, confined to container
# 1535  1536  F170056775          113.0  Cooking fire, confined to container
# 1536  1537  F170056777          113.0  Cooking fire, confined to container
# 1574  1575  F160062841          113.0  Cooking fire, confined to container
#
#                                                address  alarms  \
# 3           1700 BLOCK BELLEAU DR, PITTSBURGH PA 15212       0
# ...

# %% [markdown]
#  We suspect that Building Fires and Vehicle Fires are the most severe incident types, so let's analyze these types of fires for each neighborhood.

# %%
query_mask = fire['type_description']== "Building fire"
building = fire[query_mask]

# %%
counter = 0
for index, row in fire.iterrows():
    type = row['type_description']
    if type == "Building fire":
        counter = counter + 1
print(counter)
# Out:
# 2052

# %% [markdown]
# There are 2052 total Building Fires counted in all neighboorhoods.

# %%
import matplotlib.pyplot as plt

building["neighborhood"].value_counts().sort_index().plot(kind='bar', width=.8, figsize=(20, 6), rot=90)

plt.title('Number of Building Fires per Neighborhood')
plt.xlabel('Neighborhood')
plt.ylabel('Number of Building Fires')
plt.show()

# %%
query_mask2 = fire['type_description']== "Passenger vehicle fire"
vehicle = fire[query_mask2]

# %%
for index, row in vehicle.iterrows():
    type = row['type_description']
    if type == "Passenger vehicle fire":
        counter = counter + 1
print(counter)
# Out:
# 3157

# %% [markdown]
# There are 3157 total Passenger Vehicle Fires counted in all neighboorhoods.

# %% [markdown]
# ## vehicle["neighborhood"].value_counts().sort_index().plot(kind='bar', width=.8, figsize=(20, 6), rot=90)
#
# plt.title('Number of Passenger Vehicle Fires per Neighborhood')
# plt.xlabel('Neighborhood')
# plt.ylabel('Number of Passenger Vehicle Fires')
# plt.show()

# %% [markdown]
# We can see from the two graphs that Carrick has the most amount of Building Fires at a little over 80 and Mount Washington has the most Passenger Vehicle Fires at a little over 40. We can examine these two neighborhoods a little more closely: Carrick also has about 25 Passenger Vehicle Fires and Mount Washington has about 45 Building Fires.

# %% [markdown]
# Carrick has the higher total, so we conclude that Carrick is the unsafest neighborhood in Pittsburgh.

# %%
di = dict()
for index, rows in building.iterrows():
    item_name = rows['neighborhood']
    
    if item_name in di:
        di[item_name] = di[item_name] + 1
    else:
        di[item_name] = 1   
print(di)
# Out:
# {nan: 312, 'Fairywood': 5, 'Lincoln-Lemington-Belmar': 50, 'Carrick': 83, 'Crafton Heights': 22, 'Perry North': 25, 'Bedford Dwellings': 8, 'East Allegheny': 21, 'Homewood North': 59, 'Beltzhoover': 45, 'Crawford-Roberts': 19, 'Middle Hill': 19, 'Greenfield': 18, 'Upper Hill': 17, 'Central Lawrenceville': 16, 'Hazelwood': 38, 'East Hills': 38, 'Allentown': 41, 'Central Business District': 26, 'Bloomfield': 38, 'Sheraden': 60, 'Beechview': 38, 'Garfield': 34, 'Marshall-Shadeland': 30, 'Swisshelm Park': 3, 'Troy Hill': 23, 'Larimer': 44, 'Brighton Heights': 41, 'Highland Park': 11, 'Mount Washington': 45, 'Brookline': 43, 'Point Breeze': 13, 'Bon Air': 2, 'Fineview': 7, 'Elliott': 17, 'Overbrook': 11, 'South Oakland': 10, 'Spring Hill-City View': 25, 'South Side Flats': 33, 'Squirrel Hill North': 23, 'Summer Hill': 4, 'Stanton Heights': 17, 'Knoxville': 67, 'Manchester': 17, 'Shadyside': 32, 'Lincoln Place': 10, 'South Side Slopes': 19, 'Duquesne Heights': 13, 'Central Oakland': 21, 'H
# ...

# %%
for index, rows in vehicle.iterrows():
    item_name = rows['neighborhood']

    if item_name in di:
        di[item_name] = di[item_name] + 1
    else:
        di[item_name] = 1   
print(di)
# Out:
# {nan: 533, 'Fairywood': 12, 'Lincoln-Lemington-Belmar': 68, 'Carrick': 107, 'Crafton Heights': 32, 'Perry North': 36, 'Bedford Dwellings': 11, 'East Allegheny': 34, 'Homewood North': 86, 'Beltzhoover': 64, 'Crawford-Roberts': 29, 'Middle Hill': 32, 'Greenfield': 28, 'Upper Hill': 21, 'Central Lawrenceville': 25, 'Hazelwood': 66, 'East Hills': 59, 'Allentown': 54, 'Central Business District': 46, 'Bloomfield': 47, 'Sheraden': 74, 'Beechview': 62, 'Garfield': 45, 'Marshall-Shadeland': 54, 'Swisshelm Park': 4, 'Troy Hill': 27, 'Larimer': 68, 'Brighton Heights': 52, 'Highland Park': 18, 'Mount Washington': 92, 'Brookline': 53, 'Point Breeze': 29, 'Bon Air': 8, 'Fineview': 16, 'Elliott': 25, 'Overbrook': 16, 'South Oakland': 25, 'Spring Hill-City View': 37, 'South Side Flats': 49, 'Squirrel Hill North': 28, 'Summer Hill': 11, 'Stanton Heights': 29, 'Knoxville': 86, 'Manchester': 26, 'Shadyside': 37, 'Lincoln Place': 20, 'South Side Slopes': 40, 'Duquesne Heights': 17, 'Central Oakland': 2
# ...

# %%
series=pd.Series(di)
series = series.sort_values()
print(series)
# Out:
# New Homestead             2
# Regent Square             2
# Mount Oliver Borough      2
# Glen Hazel                3
# Arlington Heights         3
#                        ...
# Homewood North           86
# Knoxville                86
# Mount Washington         92
# Carrick                 107
# NaN                     533
# Length: 92, dtype: int64

# %% [markdown]
# New Homestead, Regent Square, and Mount Oliver Borough are tied as the safest neighborhoods in Pittsburgh.

# %% [markdown]
# # Toxic Releases By Mitchell Caplan

# %% [markdown]
# Lets get started by loading in the data for neighborhoods

# %%
import geopandas as gpd
import pandas as pd
import fpsnippets
import matplotlib.pyplot as plt

pitt = gpd.read_file('Neighbor/Neighborhoods_.shp')

pitt.head(3)
# Out:
#    OBJECTID  fid_blockg statefp10 countyfp10 tractce10 blkgrpce10  \
# 0         1         233        42        003    140500          3
# 1         2         203        42        003    140100          3
# 2         3          86        42        003    101700          2
#
#         geoid10     namelsad10 mtfcc10 funcstat10  ...  created_us  \
# 0  420031405003  Block Group 3   G5030          S  ...         SDE
# 1  420031401003  Block Group 3   G5030          S  ...         SDE
# 2  420031017002  Block Group 2   G5030          S  ...         SDE
#
#    created_da last_edite  last_edi_1  temp  pghdb_sde_  \
# 0  2020-08-14        SDE  2020-08-14  None   7968760.0
# 1  2020-08-14        SDE  2020-08-14  None  34078712.0
# 2  2020-08-14        SDE  2020-08-14  None  12751163.0
#
#                                GlobalID    Shape__Are    Shape__Len  \
# 0  a642a6b6-a2a9-48d5-acf2-3e2ce87d4bc0  8.153647e+06  14047.065024
# ...

# %% [markdown]
# Lets also load in the dataset that will be needed for them to be processed into graphs and also filter out the one their was still clean air

# %%
toxic = pd.read_csv('TRIair.csv')
toxic_no = toxic[toxic['CLEAN_AIR'] == 'N']

toxic_no.head(10)
# Out:
#        _id  TRI_FACILITY_ID   DOC_CTRL_NUM                  FACILITY_NAME  \
# 7   522794  15225SHLND2650N  1397110000799        INEOS COMPOSITES US LLC
# 8   522795  15225SHLND2650N  1397110000799        INEOS COMPOSITES US LLC
# 21  522808  15201PRSSR3419S  1397110001169           PRESSURE CHEMICAL CO
# 22  522809  15201PRSSR3419S  1397110001169           PRESSURE CHEMICAL CO
# 41  522828  15051MRCNRSTATE  1397110023227  KINDER MORGAN TRANSMIX CO LLC
# 42  522829  15051MRCNRSTATE  1397110023227  KINDER MORGAN TRANSMIX CO LLC
# 45  522832  15226MTTHW1315W  1397110036946    MATTHEWS INTERNATIONAL CORP
# 46  522833  15226MTTHW1315W  1397110036946    MATTHEWS INTERNATIONAL CORP
# 47  522834  15202PTTSB1HERR  1397110038914        PITTSBURGH INDL PLATING
# 48  522835  15202PTTSB1HERR  1397110038914        PITTSBURGH INDL PLATING
#
#         STREET_ADDRESS   CITY_NAME COUNTY_NAME  STATE_COUNTY_FIPS_CODE  \
# 7      2650 NEVILLE RD  PITTSBURGH   ALLEGHENY                   42003
# ...

# %%
# Out:
# ALLEGHENY    26549
# Name: COUNTY_NAME, dtype: int64

# %% [markdown]
# Add the releases to the approiate values into the dataframe

# %%
add_val = {"Neighborhood" : [],
          "Release" : []}
rows = 0
for i, tox in toxic_no.iterrows():
    
    possible = fpsnippets.zip_to_neighborhoods(tox['ZIP_CODE'])
    amount = tox["TOTAL_RELEASE"]
    
    if possible:
        for thing in possible:
            add_val["Neighborhood"].append(thing)
            add_val['Release'].append(amount)
            rows += 1
            
neighborhoods = pd.DataFrame(add_val,index = list(range(rows)))
neighborhoods.to_csv("revised_data.csv", index=False)

# %% [markdown]
# Basic setup and summing the data together

# %%
data = pd.read_csv('revised_data.csv')
summed_values = data.groupby('Neighborhood')['Release'].sum().reset_index()

revised_neighborhoods = pd.DataFrame(summed_values)

revised_neighborhoods.head(10)
# Out:
#         Neighborhood     Release
# 0   Allegheny Center   303411.00
# 1     Allegheny West   303411.00
# 2          Allentown     1800.00
# 3          Arlington     1800.00
# 4  Arlington Heights     1800.00
# 5         Banksville    77000.00
# 6  Bedford Dwellings      820.00
# 7          Beechview   277611.00
# 8        Beltzhoover   200611.00
# 9         Bloomfield  1066991.14

# %% [markdown]
# Get the biggest toxic releases in the top 10 neighbors

# %%
neighborhoods_sorted = revised_neighborhoods.sort_values("Release", ascending=False)

neighborhoods_sorted.head(10)
# Out:
#            Neighborhood     Release
# 36                 Hays  2543151.61
# 43        Lincoln Place  2542784.61
# 51        New Homestead  1438432.00
# 73  Squirrel Hill South  1405037.22
# 66        South Oakland  1400012.00
# 37            Hazelwood  1399192.00
# 35           Greenfield  1399192.00
# 34           Glen Hazel  1399192.00
# 27         East Liberty  1066991.14
# 33             Garfield  1066991.14

# %%
neighborhoods_sorted["Neighborhood"]
# Out:
# 36                   Hays
# 43          Lincoln Place
# 51          New Homestead
# 73    Squirrel Hill South
# 66          South Oakland
#              ...
# 78              Troy Hill
# 58            Perry South
# 57            Perry North
# 54      Northview Heights
# 31               Fineview
# Name: Neighborhood, Length: 85, dtype: object

# %% [markdown]
# We see that Hayes is the neighborhood with the most Toxic Releases. Let's plot the top 10 neighborhoods.(Measured by Million)

# %%
plt = neighborhoods_sorted.iloc[:10].plot(kind='bar', x="Neighborhood", y="Release", title="Toxic Releases by Neighborhood")

# %% [markdown]
# Let plot the bottom 10. (measured in hundreds)

# %%
neighborhoods_asc = neighborhoods_sorted.sort_values("Release")
plt2 = neighborhoods_asc.iloc[:10].plot(kind='bar', x="Neighborhood", y="Release", title="Toxic Releases by Neighborhood")

# %% [markdown]
# Lets add the data to the map of pittsburgh

# %%
pitt["TOTAL_RELEASE"] = revised_neighborhoods["Release"]

pitt.plot(column="TOTAL_RELEASE", legend=True)

# %% [markdown]
# That the conclusion of a map of pittsburgh that has the most Toxic Releases

# %%
df2 = pd.DataFrame([], 
                   columns=["beaver", "butler", "washington", "westmoreland"], 
                   index=['Hays', 'Lincoln Place', 'New Homestead',  'Squirrel Hill South', 'South Oakland', 'Hazelwood', "Greenfield", "Glen Hazel", "East Liberty", "Garfield	"])

df2.plot(kind="bar", figsize=(10,10))
